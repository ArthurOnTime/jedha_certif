# %%
import pandas as pd
import plotly.express as px

# %%
dataset = pd.read_excel('get_around_delay_analysis.xlsx')

# %%
dataset.describe(include='all').transpose()
# Out:
#                                               count unique     top   freq  \
# rental_id                                   21310.0    NaN     NaN    NaN
# car_id                                      21310.0    NaN     NaN    NaN
# checkin_type                                  21310      2  mobile  17003
# state                                         21310      2   ended  18045
# delay_at_checkout_in_minutes                16346.0    NaN     NaN    NaN
# previous_ended_rental_id                     1841.0    NaN     NaN    NaN
# time_delta_with_previous_rental_in_minutes   1841.0    NaN     NaN    NaN
#
#                                                      mean           std  \
# rental_id                                   549712.880338  13863.446964
# car_id                                      350030.603426  58206.249765
# checkin_type                                          NaN           NaN
# state                                                 NaN           NaN
# ...

# %%
px.histogram(dataset, y='time_delta_with_previous_rental_in_minutes', nbins=20)

# %%
dataset['state'].value_counts(), dataset['checkin_type'].value_counts()
# Out:
# (state
#  ended       18045
#  canceled     3265
#  Name: count, dtype: int64,
#  checkin_type
#  mobile     17003
#  connect     4307
#  Name: count, dtype: int64)

# %%
dataset[dataset['state']=='canceled'].describe()
# Out:
#            rental_id         car_id  delay_at_checkout_in_minutes  \
# count    3265.000000    3265.000000                           1.0
# mean   548637.683920  350585.309954                      -17468.0
# std     14907.810897   57254.052866                           NaN
# min    504871.000000  159533.000000                      -17468.0
# 25%    539183.000000  317572.000000                      -17468.0
# 50%    549700.000000  368593.000000                      -17468.0
# 75%    560563.000000  394869.000000                      -17468.0
# max    576195.000000  416935.000000                      -17468.0
#
#        previous_ended_rental_id  time_delta_with_previous_rental_in_minutes
# count                229.000000                                  229.000000
# mean              550913.327511                                  294.890830
# std                11955.397600                                  250.591601
# ...

# %%
dataset[dataset['state']=='canceled']
# Out:
#        rental_id  car_id checkin_type     state  delay_at_checkout_in_minutes  \
# 0         505000  363965       mobile  canceled                           NaN
# 3         508865  299063      connect  canceled                           NaN
# 8         512475  322502       mobile  canceled                           NaN
# 10        513743  330658       mobile  canceled                           NaN
# 11        514161  366037      connect  canceled                           NaN
# ...          ...     ...          ...       ...                           ...
# 21283     569325  345079       mobile  canceled                           NaN
# 21287     569764  405347       mobile  canceled                           NaN
# 21288     570001  386413      connect  canceled                           NaN
# 21297     571481  311841       mobile  canceled                           NaN
# 21300     572293  355023      connect  canceled                           NaN
#
# ...

# %%
px.scatter(dataset[dataset['state']=='canceled'],y='delay_at_checkout_in_minutes',x='rental_id')
